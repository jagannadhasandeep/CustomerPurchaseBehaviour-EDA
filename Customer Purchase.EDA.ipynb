# %%
#Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Dataset

data = pd.read_csv(r"C:\Users\sandy\sandeep\datasets\customer data.csv")

# %%
data
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0      40       1   66120.267939                  8                0
# 1      20       1   23579.773583                  4                2
# 2      27       1  127821.306432                 11                2
# 3      24       1  137798.623120                 19                3
# 4      31       1   99300.964220                 19                1
# ...   ...     ...            ...                ...              ...
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
data.isnull()
# Out:
#         Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0     False   False         False              False            False
# 1     False   False         False              False            False
# 2     False   False         False              False            False
# 3     False   False         False              False            False
# 4     False   False         False              False            False
# ...     ...     ...           ...                ...              ...
# 1495  False   False         False              False            False
# 1496  False   False         False              False            False
# 1497  False   False         False              False            False
# 1498  False   False         False              False            False
# 1499  False   False         False              False            False
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
data.isnull().sum
# Out:
# <bound method DataFrame.sum of         Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0     False   False         False              False            False
# 1     False   False         False              False            False
# 2     False   False         False              False            False
# 3     False   False         False              False            False
# 4     False   False         False              False            False
# ...     ...     ...           ...                ...              ...
# 1495  False   False         False              False            False
# 1496  False   False         False              False            False
# 1497  False   False         False              False            False
# 1498  False   False         False              False            False
# 1499  False   False         False              False            False
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
data.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
data.tail(20)
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1480   39       0   34204.347340                 17                3
# 1481   49       0   95780.387385                 18                0
# 1482   32       1   35979.688201                 11                1
# 1483   55       0   81936.808225                  6                1
# 1484   68       0   80311.223269                 14                2
# 1485   21       1  120794.999552                 10                0
# 1486   28       1  141304.733075                  0                1
# 1487   41       0  116615.115835                 19                2
# 1488   22       0   55799.552653                  9                4
# 1489   19       0   26090.748109                  0                2
# 1490   18       1   83126.660956                 20                3
# 1491   30       0   71611.955361                 20                1
# 1492   63       0   71874.591294                 10                2
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0      40       1   66120.267939                  8                0
# 1      20       1   23579.773583                  4                2
# 2      27       1  127821.306432                 11                2
# 3      24       1  137798.623120                 19                3
# 4      31       1   99300.964220                 19                1
# ...   ...     ...            ...                ...              ...
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
data.shape[1]
# Out:
# 9

# %%
data.shape[0]
# Out:
# 1500

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1500 non-null   int64
#  1   Gender              1500 non-null   int64
#  2   AnnualIncome        1500 non-null   float64
#  3   NumberOfPurchases   1500 non-null   int64
#  4   ProductCategory     1500 non-null   int64
#  5   TimeSpentOnWebsite  1500 non-null   float64
#  6   LoyaltyProgram      1500 non-null   int64
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 105.6 KB

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
plt.figsize = (10,20)
sns.histplot(data ,y="Age",x="AnnualIncome")
# Out:
# <Axes: xlabel='AnnualIncome', ylabel='Age'>

# %%
plt.figsize = (1000,1000)
sns.displot(data, y="ProductCategory",x="NumberOfPurchases")

# %%
plt.figsize = (10,20)
sns.relplot(data ,y="Gender", x="TimeSpentOnWebsite")

# %%
plt.figsize = (100,100)
sns.barplot(data , y="ProductCategory", x="PurchaseStatus")
# Out:
# <Axes: xlabel='PurchaseStatus', ylabel='ProductCategory'>

# %%
sns.lmplot(y="NumberOfPurchases", x="TimeSpentOnWebsite", data=data)

# %%
sns.relplot(data=data, y="DiscountsAvailed", x="LoyaltyProgram", kind="line")

# %%
plt.figsize = (1000,1000)
sns.catplot(data=data, x="Gender", y="NumberOfPurchases")

# %%
top_5_Annual_Income= data.nlargest(5, 'AnnualIncome')
print("\nTop 5 Annual Income:")
print(top_5_Annual_Income)
# Out:
# Top 5 Annual Income:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 468    18       1  149785.176481                 10                0
# 1169   27       1  149716.711239                 16                3
# 715    19       0  149570.591001                 19                2
# 657    19       0  149523.463892                  5                3
# 868    50       0  149406.877105                 13                4
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 468            38.979469               0                 5               1
# 1169           48.042872               0                 3               1
# 715            21.763856               0                 2               0
# 657            13.579032               0                 4               0
# 868            12.504808               1                 4               1

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='DiscountsAvailed', hue='NumberOfPurchases', bins=10, kde=True, multiple="stack")

# Add labels
plt.xlabel('DiscountsAvailed')
plt.ylabel('NumberOfPurchases')

# Show the plot
plt.show()

# %%
corr_matrix = data.select_dtypes(include=['number']).corr()

# Create a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, cmap=sns.cubehelix_palette(as_cmap=True), linewidths=0.5)

plt.show()

# %%
sns.violinplot(x="Gender", y="AnnualIncome", data=data)

plt.xlabel("Gender")
plt.ylabel("AnnualIncome")
plt.show()

# %%
sns.pairplot(data.select_dtypes(include=['number']))

plt.show()

# %%
status_counts = data['NumberOfPurchases'].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.show()
